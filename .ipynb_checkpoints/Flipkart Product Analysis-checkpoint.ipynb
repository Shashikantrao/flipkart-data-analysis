# %% [markdown]
# ## Flipkart Product Analysis

# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use("default")
sns.set(style="whitegrid")

# %% [markdown]
# ### Load Dataset

# %%
df = pd.read_csv("flipkard.csv")
df.head()
# Out:
#    product_id      product_name        category   brand        seller  \
# 0  FKP0000001  Adidas Ultra 664            Toys  Adidas     MegaStore
# 1  FKP0000002     LG Series 124         Fashion      LG     ValueKart
# 2  FKP0000003    Redmi Model 35          Beauty   Redmi    SmartDeals
# 3  FKP0000004  Sony Edition 769            Toys    Sony  UrbanRetails
# 4  FKP0000005    Boat Prime 291  Home & Kitchen    Boat     RetailHub
#
#   seller_city     price  discount_percent  final_price  rating  ...  weight_g  \
# 0   Hyderabad  35547.34                15     30215.24     1.9  ...   3038.23
# 1      Mumbai  30693.79                10     27624.41     3.2  ...   1921.82
# 2   Ahmedabad  51214.50                40     30728.70     4.4  ...   1143.49
# 3       Delhi  33168.49                30     23217.94     2.8  ...   3644.81
# 4        Pune  14181.34                 0     14181.34     3.7  ...    310.33
#
#    warranty_months  color      size  return_policy_days  is_returnable  \
# 0               36  Green        XL                  30           True
# 1                0   Grey  One Size                   7           True
# 2               12  Black         M                   0          False
# 3               24  Black         L                   0          False
# 4                0   Blue       NaN                  30           True
#
#    payment_modes shipping_weight_g product_score  seller_rating
# 0       COD,CARD       3483.592454          6.78           3.28
# 1       UPI,CARD       2091.473835         50.78           3.42
# 2   COD,UPI,CARD       1242.770494          4.24           4.23
# 3    CARD,Wallet       3891.222716          1.38           3.45
# 4    CARD,Wallet        386.061014         79.27           4.90
#
# [5 rows x 25 columns]

# %%
df.shape
# Out:
# (80000, 25)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80000 entries, 0 to 79999
# Data columns (total 25 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   product_id          80000 non-null  object
#  1   product_name        80000 non-null  object
#  2   category            80000 non-null  object
#  3   brand               80000 non-null  object
#  4   seller              80000 non-null  object
#  5   seller_city         80000 non-null  object
#  6   price               80000 non-null  float64
#  7   discount_percent    80000 non-null  int64
#  8   final_price         80000 non-null  float64
#  9   rating              80000 non-null  float64
#  10  review_count        80000 non-null  int64
#  11  stock_available     80000 non-null  int64
#  12  units_sold          80000 non-null  int64
#  13  listing_date        80000 non-null  object
#  14  delivery_days       80000 non-null  int64
#  15  weight_g            80000 non-null  float64
#  16  warranty_months     80000 non-null  int64
#  17  color               80000 non-null  object
#  18  size                66516 non-null  object
#  19  return_policy_days  80000 non-null  int64
#  20  is_returnable       80000 non-null  bool
#  21  payment_modes       80000 non-null  object
#  22  shipping_weight_g   80000 non-null  float64
#  23  product_score       80000 non-null  float64
#  24  seller_rating       80000 non-null  float64
# dtypes: bool(1), float64(7), int64(7), object(10)
# memory usage: 14.7+ MB

# %%
df.describe(include="all").T
# Out:
#                       count unique                top   freq          mean  \
# product_id            80000  80000         FKP0000001      1           NaN
# product_name          80000  48801  Adidas Series 497      7           NaN
# category              80000      8               Toys  10151           NaN
# brand                 80000     15               Puma   5409           NaN
# seller                80000      8          ValueKart  10109           NaN
# seller_city           80000      8               Pune  10138           NaN
# price               80000.0    NaN                NaN    NaN  30137.256454
# discount_percent    80000.0    NaN                NaN    NaN     21.350625
# final_price         80000.0    NaN                NaN    NaN    23697.7806
# rating              80000.0    NaN                NaN    NaN      2.999671
# review_count        80000.0    NaN                NaN    NaN  25102.249875
# stock_available     80000.0    NaN                NaN    NaN    499.194262
# units_sold          80000.0    NaN                NaN    NaN   2507.515775
# listing_date          80000   2001         2018-12-21     61           NaN
# delivery_days       80000.0    NaN                NaN    NaN      6.006325
# weight_g            80000.0    NaN                NaN    NaN   2522.224622
# warranty_months     80000.0    NaN                NaN    NaN        15.564
# color                 80000      8             Silver  10101           NaN
# size                  66516      5                  L  13450           NaN
# return_policy_days  80000.0    NaN                NaN    NaN      12.36225
# is_returnable         80000      2               True  64034           NaN
# payment_modes         80000      4        CARD,Wallet  20114           NaN
# shipping_weight_g   80000.0    NaN                NaN    NaN   2899.960047
# product_score       80000.0    NaN                NaN    NaN      50.67375
# seller_rating       80000.0    NaN                NaN    NaN      4.002218
#
#                              std       min          25%          50%  \
# product_id                   NaN       NaN          NaN          NaN
# product_name                 NaN       NaN          NaN          NaN
# category                     NaN       NaN          NaN          NaN
# brand                        NaN       NaN          NaN          NaN
# seller                       NaN       NaN          NaN          NaN
# seller_city                  NaN       NaN          NaN          NaN
# price               17274.048682    200.14    15180.205    30164.455
# discount_percent       16.354446       0.0         10.0         20.0
# final_price         14726.821259    101.08   11341.7225    22571.265
# rating                  1.156238       1.0          2.0          3.0
# review_count        14428.769942       0.0      12605.0      25166.5
# stock_available       288.917706       0.0        249.0        499.0
# units_sold           1439.519972       0.0       1261.0       2513.0
# listing_date                 NaN       NaN          NaN          NaN
# delivery_days            3.16063       1.0          3.0          6.0
# weight_g             1428.287966     50.02    1283.1175      2524.55
# warranty_months         12.91307       0.0          6.0         12.0
# color                        NaN       NaN          NaN          NaN
# size                         NaN       NaN          NaN          NaN
# return_policy_days     10.019794       0.0          7.0         10.0
# is_returnable                NaN       NaN          NaN          NaN
# payment_modes                NaN       NaN          NaN          NaN
# shipping_weight_g    1650.921766  53.15525  1469.583781  2892.632502
# product_score          28.562732       1.0        25.95        50.67
# seller_rating           0.577595       3.0          3.5         4.01
#
#                             75%          max
# product_id                  NaN          NaN
# product_name                NaN          NaN
# category                    NaN          NaN
# brand                       NaN          NaN
# seller                      NaN          NaN
# seller_city                 NaN          NaN
# price                45077.0875      59995.8
# discount_percent           40.0         50.0
# final_price          34521.0575      59995.8
# rating                      4.0          5.0
# review_count            37666.0      49999.0
# stock_available           749.0        999.0
# units_sold               3754.0       4999.0
# listing_date                NaN          NaN
# delivery_days               9.0         11.0
# weight_g               3753.195      4999.92
# warranty_months            24.0         36.0
# color                       NaN          NaN
# size                        NaN          NaN
# return_policy_days         15.0         30.0
# is_returnable               NaN          NaN
# payment_modes               NaN          NaN
# shipping_weight_g   4304.695597  6234.757448
# product_score             75.43        100.0
# seller_rating               4.5          5.0

# %% [markdown]
# ### Data Cleaning

# %%
df.isnull().sum()
# Out:
# product_id                0
# product_name              0
# category                  0
# brand                     0
# seller                    0
# seller_city               0
# price                     0
# discount_percent          0
# final_price               0
# rating                    0
# review_count              0
# stock_available           0
# units_sold                0
# listing_date              0
# delivery_days             0
# weight_g                  0
# warranty_months           0
# color                     0
# size                  13484
# return_policy_days        0
# is_returnable             0
# payment_modes             0
# shipping_weight_g         0
# product_score             0
# seller_rating             0
# dtype: int64

# %%
# Fill numeric columns
num_cols = df.select_dtypes(include=np.number).columns
df[num_cols] = df[num_cols].fillna(df[num_cols].median())

# Fill categorical columns
cat_cols = df.select_dtypes(include="object").columns
df[cat_cols] = df[cat_cols].fillna("Unknown")

# %%
df["listing_date"] = pd.to_datetime(df["listing_date"])

# %% [markdown]
# ### Feature Engineering

# %%
df["discount_amount"] = df["price"] - df["final_price"]

df["revenue"] = df["final_price"] * df["units_sold"]

df["stock_status"] = np.where(df["stock_available"] > 0, "In Stock", "Out of Stock")

df["listing_month"] = df["listing_date"].dt.month
df["listing_year"] = df["listing_date"].dt.year

# %% [markdown]
# ### Overall Business Metrics (Numeric Insights)

# %%
df[[
    "price","final_price","discount_percent","rating",
    "units_sold","revenue","review_count","seller_rating"
]].describe()
# Out:
#               price   final_price  discount_percent        rating  \
# count  80000.000000  80000.000000      80000.000000  80000.000000
# mean   30137.256454  23697.780600         21.350625      2.999671
# std    17274.048682  14726.821259         16.354446      1.156238
# min      200.140000    101.080000          0.000000      1.000000
# 25%    15180.205000  11341.722500         10.000000      2.000000
# 50%    30164.455000  22571.265000         20.000000      3.000000
# 75%    45077.087500  34521.057500         40.000000      4.000000
# max    59995.800000  59995.800000         50.000000      5.000000
#
#          units_sold       revenue  review_count  seller_rating
# count  80000.000000  8.000000e+04  80000.000000   80000.000000
# mean    2507.515775  5.952385e+07  25102.249875       4.002218
# std     1439.519972  5.472902e+07  14428.769942       0.577595
# min        0.000000  0.000000e+00      0.000000       3.000000
# 25%     1261.000000  1.573443e+07  12605.000000       3.500000
# 50%     2513.000000  4.321070e+07  25166.500000       4.010000
# 75%     3754.000000  8.929339e+07  37666.000000       4.500000
# max     4999.000000  2.964058e+08  49999.000000       5.000000

# %% [markdown]
# ### Category-Level Analysis

# %%
# Revenue by Category
category_revenue = df.groupby("category")["revenue"].sum().sort_values(ascending=False)
category_revenue.head(10)
# Out:
# category
# Toys              6.064486e+11
# Beauty            6.058160e+11
# Fashion           5.995559e+11
# Electronics       5.994879e+11
# Appliances        5.940603e+11
# Sports            5.890503e+11
# Mobiles           5.843309e+11
# Home & Kitchen    5.831580e+11
# Name: revenue, dtype: float64

# %%
category_revenue.head(10).plot(kind="bar", figsize=(10,5), title="Top Categories by Revenue")
plt.ylabel("Revenue")
plt.show()

# %% [markdown]
# ### Brand Performance Analysis

# %%
top_brands = df.groupby("brand")["revenue"].sum().sort_values(ascending=False).head(10)
top_brands
# Out:
# brand
# Nike        3.237334e+11
# Adidas      3.213176e+11
# Puma        3.210516e+11
# Apple       3.209929e+11
# Boat        3.206118e+11
# Prestige    3.196137e+11
# HP          3.183560e+11
# Dell        3.177141e+11
# Reebok      3.171473e+11
# LG          3.167956e+11
# Name: revenue, dtype: float64

# %%
top_brands.plot(kind="barh", figsize=(10,5), title="Top Brands by Revenue")
plt.show()

# %% [markdown]
# ### Price vs Rating Analysis

# %%
sns.scatterplot(data=df, x="final_price", y="rating")
plt.title("Price vs Rating")
plt.show()

# %% [markdown]
# ### Discount Impact on Sales

# %%
sns.regplot(data=df, x="discount_percent", y="units_sold")
plt.title("Discount vs Units Sold")
plt.show()

# %% [markdown]
# ### Seller Performance

# %%
#Top sellers by revenue
top_sellers = df.groupby("seller")["revenue"].sum().sort_values(ascending=False).head(10)
top_sellers
# Out:
# seller
# UrbanRetails    6.043700e+11
# QuickShop       6.014686e+11
# BestBuy         5.964748e+11
# SuperMart       5.953379e+11
# ValueKart       5.948731e+11
# MegaStore       5.937561e+11
# SmartDeals      5.881427e+11
# RetailHub       5.874846e+11
# Name: revenue, dtype: float64

# %%
#Seller Rating vs Revenue
sns.scatterplot(data=df, x="seller_rating", y="revenue")
plt.title("Seller Rating vs Revenue")
plt.show()

# %% [markdown]
# ### City-wise Seller Analysis

# %%
city_sales = df.groupby("seller_city")["revenue"].sum().sort_values(ascending=False).head(10)
city_sales
# Out:
# seller_city
# Pune         6.122199e+11
# Delhi        6.059920e+11
# Chennai      6.030160e+11
# Hyderabad    5.997924e+11
# Mumbai       5.931760e+11
# Ahmedabad    5.889250e+11
# Bengaluru    5.802936e+11
# Kolkata      5.784931e+11
# Name: revenue, dtype: float64

# %%
city_sales.plot(kind="bar", figsize=(10,5), title="Top Seller Cities by Revenue")
plt.show()

# %% [markdown]
# ### Delivery & Logistics Analysis

# %%
sns.boxplot(data=df, x="delivery_days")
plt.title("Delivery Days Distribution")
plt.show()

# %%
sns.scatterplot(data=df, x="delivery_days", y="rating")
plt.title("Delivery Days vs Rating")
plt.show()

# %% [markdown]
# ### Return & Payment Analysis

# %%
df["is_returnable"].value_counts().plot(kind="pie", autopct="%1.1f%%")
plt.title("Returnable Products")
plt.show()

# %%
df["payment_modes"].value_counts().head(10)
# Out:
# payment_modes
# CARD,Wallet     20114
# UPI,CARD        20037
# COD,UPI,CARD    19977
# COD,CARD        19872
# Name: count, dtype: int64

# %% [markdown]
# ### Product Score Analysis

# %%
sns.histplot(df["product_score"], bins=20, kde=True)
plt.title("Product Score Distribution")
plt.show()

# %%
sns.scatterplot(data=df, x="product_score", y="units_sold")
plt.title("Product Score vs Units Sold")
plt.show()

# %% [markdown]
# ### Correlation Analysis

# %%
corr = df[num_cols].corr()

plt.figure(figsize=(12,8))
sns.heatmap(corr, cmap="coolwarm", annot=False)
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# ### Monthly Listing Trend

# %%
monthly_listings = df.groupby("listing_month")["product_id"].count()

monthly_listings.plot(marker="o", title="Monthly Product Listings")
plt.ylabel("Number of Products")
plt.show()

# %% [markdown]
# ### Top Products by Revenue

# %%
df.sort_values("revenue", ascending=False)[[
    "product_name","category","brand","final_price","units_sold","revenue"
]].head(10)
# Out:
#                product_name     category      brand  final_price  units_sold  \
# 11084       Nike Series 426       Beauty       Nike     59711.08        4964
# 11725    Whirlpool Prime 29       Beauty  Whirlpool     59175.48        4992
# 10880          LG Model 366  Electronics         LG     59186.39        4978
# 79233        HP Edition 280       Beauty         HP     57711.63        4977
# 60941   Prestige Series 964       Sports   Prestige     58922.68        4866
# 75334       Nike Series 241      Fashion       Nike     58352.26        4912
# 75534   Prestige Series 397         Toys   Prestige     59881.66        4779
# 58430  Whirlpool Series 987   Appliances  Whirlpool     59228.17        4781
# 60765          LG Series 64      Mobiles         LG     59502.67        4753
# 43004        Boat Prime 637       Beauty       Boat     56886.79        4968
#
#             revenue
# 11084  2.964058e+08
# 11725  2.954040e+08
# 10880  2.946298e+08
# 79233  2.872308e+08
# 60941  2.867178e+08
# 75334  2.866263e+08
# 75534  2.861745e+08
# 58430  2.831699e+08
# 60765  2.828162e+08
# 43004  2.826136e+08

# %% [markdown]
# ### PRICE ELASTICITY & DEMAND SENSITIVITY

# %%
#Units Sold vs Price
sns.scatterplot(data=df, x="final_price", y="units_sold")
plt.title("Final Price vs Units Sold")
plt.show()

# %%
#Units Sold vs Discount %
sns.regplot(data=df, x="discount_percent", y="units_sold")
plt.title("Discount % vs Units Sold")
plt.show()

# %%
#Category-wise Discount Sensitivity
category_discount = df.groupby("category")[["discount_percent", "units_sold"]].mean()
category_discount.sort_values("units_sold", ascending=False).head(10)
# Out:
#                 discount_percent   units_sold
# category
# Home & Kitchen         21.346410  2526.267848
# Appliances             21.377996  2525.743255
# Electronics            21.432551  2524.123259
# Toys                   21.482120  2518.566545
# Fashion                21.226190  2498.276786
# Mobiles                21.471123  2494.989701
# Beauty                 21.315633  2489.529622
# Sports                 21.152729  2482.959139

# %% [markdown]
# ### PRODUCT LIFECYCLE ANALYSIS

# %%
#Days Since Listing
df["days_since_listing"] = (pd.Timestamp.today() - df["listing_date"]).dt.days

# %%
#Days Since Listing vs Units Sold
sns.scatterplot(data=df, x="days_since_listing", y="units_sold")
plt.title("Product Age vs Units Sold")
plt.show()

# %%
#Revenue Decay Over Time
sns.regplot(data=df, x="days_since_listing", y="revenue")
plt.title("Product Age vs Revenue")
plt.show()

# %% [markdown]
# ### INVENTORY & STOCK RISK ANALYSIS

# %%
#Stock vs Units Sold
sns.scatterplot(data=df, x="stock_available", y="units_sold")
plt.title("Stock Available vs Units Sold")
plt.show()

# %%
#Days to Stock Out (Approximation)
df["days_to_stockout"] = df["stock_available"] / (df["units_sold"] + 1)

# %%
df[["product_name", "stock_available", "units_sold", "days_to_stockout"]].sort_values(
    "days_to_stockout"
).head(10)
# Out:
#               product_name  stock_available  units_sold  days_to_stockout
# 8094    Philips Edition 53                0        3075               0.0
# 58935       Puma Prime 700                0        3023               0.0
# 32286       Boat Ultra 753                0        2269               0.0
# 64145       Nike Model 929                0        4030               0.0
# 5568   Whirlpool Model 234                0        1425               0.0
# 3448   Whirlpool Prime 988                0        4386               0.0
# 8838       Puma Series 691                0        2929               0.0
# 45279    Adidas Series 424                0        4775               0.0
# 2203        Puma Ultra 230                0        3744               0.0
# 11111    Philips Model 425                0          72               0.0

# %% [markdown]
# ### RETURN RISK ANALYSIS

# %%
#Returnable vs Non-Returnable
df["is_returnable"].value_counts().plot(kind="bar", title="Returnable Products")
plt.show()

# %%
#Delivery Days vs Returns
sns.boxplot(data=df, x="is_returnable", y="delivery_days")
plt.title("Delivery Days vs Returnable Status")
plt.show()

# %%
#Category-wise Return Rate
return_category = df.groupby("category")["is_returnable"].mean()
return_category.sort_values(ascending=False).head(10)
# Out:
# category
# Mobiles           0.805331
# Sports            0.804607
# Toys              0.803862
# Appliances        0.802126
# Home & Kitchen    0.799959
# Fashion           0.796925
# Beauty            0.795621
# Electronics       0.795066
# Name: is_returnable, dtype: float64

# %% [markdown]
# ### SELLER QUALITY & TRUST ANALYSIS

# %%
#Seller Rating vs Revenue
sns.scatterplot(data=df, x="seller_rating", y="revenue")
plt.title("Seller Rating vs Revenue")
plt.show()

# %%
# Seller Rating vs Delivery Days
sns.scatterplot(data=df, x="seller_rating", y="delivery_days")
plt.title("Seller Rating vs Delivery Days")
plt.show()

# %%
# Seller Scorecard
seller_score = df.groupby("seller").agg({
    "revenue": "sum",
    "seller_rating": "mean",
    "delivery_days": "mean",
    "units_sold": "sum"
}).sort_values("revenue", ascending=False)

seller_score.head(10)
# Out:
#                    revenue  seller_rating  delivery_days  units_sold
# seller
# UrbanRetails  6.043700e+11       4.008920       6.045992    25330100
# QuickShop     6.014686e+11       4.003991       6.012018    25181220
# BestBuy       5.964748e+11       4.008672       5.961022    25241641
# SuperMart     5.953379e+11       3.998739       6.030868    25135503
# ValueKart     5.948731e+11       3.999275       6.029578    25197675
# MegaStore     5.937561e+11       3.995456       6.001000    25153095
# SmartDeals    5.881427e+11       3.999773       6.015442    24670820
# RetailHub     5.874846e+11       4.002910       5.953722    24691208

# %% [markdown]
# ### PAYMENT MODE ANALYSIS

# %%
#Payment Mode Distribution
df["payment_modes"].value_counts().head(10).plot(kind="bar")
plt.title("Top Payment Modes")
plt.show()

# %%
#Payment Mode vs Revenue
payment_revenue = df.groupby("payment_modes")["revenue"].sum().sort_values(ascending=False)
payment_revenue.head(10)
# Out:
# payment_modes
# UPI,CARD        1.203091e+12
# CARD,Wallet     1.190458e+12
# COD,UPI,CARD    1.187428e+12
# COD,CARD        1.180931e+12
# Name: revenue, dtype: float64

# %% [markdown]
# ### PRODUCT SCORE DEEP DIVE

# %%
# Product Score Distribution
sns.histplot(df["product_score"], bins=20, kde=True)
plt.title("Product Score Distribution")
plt.show()

# %%
#Product Score vs Units Sold
sns.regplot(data=df, x="product_score", y="units_sold")
plt.title("Product Score vs Units Sold")
plt.show()

# %%
# Product Score vs Revenue
sns.regplot(data=df, x="product_score", y="revenue")
plt.title("Product Score vs Revenue")
plt.show()

# %% [markdown]
# ### LOGISTICS & DELIVERY PERFORMANCE

# %%
# Delivery Days Distribution
sns.histplot(df["delivery_days"], bins=15)
plt.title("Delivery Days Distribution")
plt.show()

# %%
#Delivery Days vs Rating
sns.scatterplot(data=df, x="delivery_days", y="rating")
plt.title("Delivery Days vs Customer Rating")
plt.show()

# %% [markdown]
# ### TOP & BOTTOM PRODUCT ANALYSIS

# %%
#Top 10 Products by Revenue
df.sort_values("revenue", ascending=False)[
    ["product_name", "category", "brand", "revenue"]
].head(10)
# Out:
#                product_name     category      brand       revenue
# 11084       Nike Series 426       Beauty       Nike  2.964058e+08
# 11725    Whirlpool Prime 29       Beauty  Whirlpool  2.954040e+08
# 10880          LG Model 366  Electronics         LG  2.946298e+08
# 79233        HP Edition 280       Beauty         HP  2.872308e+08
# 60941   Prestige Series 964       Sports   Prestige  2.867178e+08
# 75334       Nike Series 241      Fashion       Nike  2.866263e+08
# 75534   Prestige Series 397         Toys   Prestige  2.861745e+08
# 58430  Whirlpool Series 987   Appliances  Whirlpool  2.831699e+08
# 60765          LG Series 64      Mobiles         LG  2.828162e+08
# 43004        Boat Prime 637       Beauty       Boat  2.826136e+08

# %%
#Bottom 10 Products by Revenue

df.sort_values("revenue")[["product_name", "category", "brand", "revenue"]].head(10)
# Out:
#               product_name        category      brand  revenue
# 55613  Whirlpool Series 86          Sports  Whirlpool      0.0
# 76135      Boat Series 442          Sports       Boat      0.0
# 39128     Puma Edition 196         Mobiles       Puma      0.0
# 8801        Sony Model 761          Sports       Sony      0.0
# 55922     Reebok Prime 856  Home & Kitchen     Reebok      0.0
# 75397        LG Series 453  Home & Kitchen         LG      0.0
# 25277       Nike Series 21          Beauty       Nike      0.0
# 60944  Prestige Series 683            Toys   Prestige      0.0
# 35785       Dell Ultra 343            Toys       Dell      0.0
# 9905        Nike Ultra 130          Sports       Nike      0.0

# %% [markdown]
# ### CATEGORY PERFORMANCE SCORECARD

# %%
category_scorecard = df.groupby("category").agg({
    "revenue": "sum",
    "units_sold": "mean",
    "rating": "mean",
    "delivery_days": "mean",
    "discount_percent": "mean"
}).sort_values("revenue", ascending=False)

category_scorecard.head(10)
# Out:
#                      revenue   units_sold    rating  delivery_days  \
# category
# Toys            6.064486e+11  2518.566545  3.004669       5.986405
# Beauty          6.058160e+11  2489.529622  3.000832       6.036953
# Fashion         5.995559e+11  2498.276786  3.019722       5.980159
# Electronics     5.994879e+11  2524.123259  3.001433       6.060287
# Appliances      5.940603e+11  2525.743255  3.016628       5.956173
# Sports          5.890503e+11  2482.959139  2.989434       6.047271
# Mobiles         5.843309e+11  2494.989701  2.973021       5.998082
# Home & Kitchen  5.831580e+11  2526.267848  2.990945       5.984533
#
#                 discount_percent
# category
# Toys                   21.482120
# Beauty                 21.315633
# Fashion                21.226190
# Electronics            21.432551
# Appliances             21.377996
# Sports                 21.152729
# Mobiles                21.471123
# Home & Kitchen         21.346410
